# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", 200)

# %%
df = pd.read_csv('./data/malicious_dataset.csv')
attack_classes = pd.read_csv("./data/attack_labels.csv")
df.head(1)
# Out:
#    ip.version  ip.hdr_len  ip.tos       ip.id    ip.flags  ip.flags.rb  \
# 0           4          20     NaN  0x0000f96f  0x00004000            0
#
#    ip.flags.df  ip.flags.mf  ip.frag_offset  ip.ttl  ip.proto ip.checksum  \
# 0            1            0               0      64         6  0x000080fc
#
#       ip.src         ip.dst  ip.len  ip.dsfield  tcp.srcport  tcp.dstport  \
# 0  10.0.2.15  91.189.88.152      40  0x00000000        34850           80
#
#    tcp.seq  tcp.ack  tcp.len  tcp.hdr_len  tcp.srcport.1  tcp.dstport.1  \
# 0        1        1        0           20          34850             80
#
#     tcp.flags  tcp.flags.fin  tcp.flags.syn  tcp.flags.reset  tcp.flags.push  \
# 0  0x00000011              1              0                0               0
#
#    tcp.flags.ack  tcp.flags.urg  tcp.flags.cwr  tcp.window_size tcp.checksum  \
# 0              1              0              0            65535   0x000073a9
#
#    tcp.urgent_pointer  tcp.options.mss_val
# 0                   0                  NaN

# %%
attack_classes.head()
# Out:
#            ip          label
# 0  172.16.0.3   nmap_tcp_syn
# 1  172.16.0.4  nmap_tcp_conn
# 2  172.16.0.5  nmap_tcp_null
# 3  172.16.0.6  nmap_tcp_xmas
# 4  172.16.0.7   nmap_tcp_fin

# %%
df_labeled = df.merge(attack_classes, how='inner', left_on='ip.src', right_on='ip')
df_labeled.drop(['ip'], axis=1, inplace=True)
df_labeled.head()
# Out:
#    ip.version  ip.hdr_len  ip.tos       ip.id    ip.flags  ip.flags.rb  \
# 0           4          20     NaN  0x0000d965  0x00000000            0
# 1           4          20     NaN  0x00002f3f  0x00000000            0
# 2           4          20     NaN  0x0000a7aa  0x00000000            0
# 3           4          20     NaN  0x0000b67b  0x00000000            0
# 4           4          20     NaN  0x00002d5f  0x00000000            0
#
#    ip.flags.df  ip.flags.mf  ip.frag_offset  ip.ttl  ip.proto ip.checksum  \
# 0            0            0               0      52         6  0x0000ed3f
# 1            0            0               0      54         6  0x00009566
# 2            0            0               0      49         6  0x000021fb
# 3            0            0               0      40         6  0x00001c2a
# 4            0            0               0      37         6  0x0000a846
#
#        ip.src       ip.dst  ip.len  ip.dsfield  tcp.srcport  tcp.dstport  \
# 0  172.16.0.3  10.10.10.10      44  0x00000000        65085          445
# 1  172.16.0.3  10.10.10.10      44  0x00000000        65085           21
# 2  172.16.0.3  10.10.10.10      44  0x00000000        65085          993
# 3  172.16.0.3  10.10.10.10      44  0x00000000        65085          135
# 4  172.16.0.3  10.10.10.10      44  0x00000000        65085         1723
#
#    tcp.seq  tcp.ack  tcp.len  tcp.hdr_len  tcp.srcport.1  tcp.dstport.1  \
# 0        0        0        0           24          65085            445
# 1        0        0        0           24          65085             21
# 2        0        0        0           24          65085            993
# 3        0        0        0           24          65085            135
# 4        0        0        0           24          65085           1723
#
#     tcp.flags  tcp.flags.fin  tcp.flags.syn  tcp.flags.reset  tcp.flags.push  \
# 0  0x00000002              0              1                0               0
# 1  0x00000002              0              1                0               0
# 2  0x00000002              0              1                0               0
# 3  0x00000002              0              1                0               0
# 4  0x00000002              0              1                0               0
#
#    tcp.flags.ack  tcp.flags.urg  tcp.flags.cwr  tcp.window_size tcp.checksum  \
# 0              0              0              0             1024   0x0000ccdf
# 1              0              0              0             1024   0x0000ce87
# 2              0              0              0             1024   0x0000cabb
# 3              0              0              0             1024   0x0000ce15
# 4              0              0              0             1024   0x0000c7e1
#
#    tcp.urgent_pointer  tcp.options.mss_val         label
# 0                   0               1460.0  nmap_tcp_syn
# 1                   0               1460.0  nmap_tcp_syn
# 2                   0               1460.0  nmap_tcp_syn
# 3                   0               1460.0  nmap_tcp_syn
# 4                   0               1460.0  nmap_tcp_syn
